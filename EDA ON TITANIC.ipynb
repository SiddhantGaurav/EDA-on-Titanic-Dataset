# %% [markdown]
# # EDA ON TITANIC DATASET

# %% [markdown]
# ## Data import/preparation

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pat=pd.read_csv("titanic_train.csv")

# %%
df=pat

# %% [markdown]
# # Data processing

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ## STATISTICAL ANALYSIS

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 169          170         0       3
# 485          486         0       3
# 64            65         0       1
# 238          239         0       2
# 861          862         0       2
# 314          315         0       2
# 567          568         0       3
# 659          660         0       1
# 814          815         0       3
# 743          744         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 169                                Ling, Mr. Lee    male  28.0      0      0
# 485                       Lefebre, Miss. Jeannie  female   NaN      3      1
# 64                         Stewart, Mr. Albert A    male   NaN      0      0
# 238              Pengelly, Mr. Frederick William    male  19.0      0      0
# 861                  Giles, Mr. Frederick Edward    male  21.0      1      0
# 314                           Hart, Mr. Benjamin    male  43.0      1      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Name'].value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.value_counts(dropna=False)
# Out:
# PassengerId  Survived  Pclass  Name                                      Sex     Age   SibSp  Parch  Ticket      Fare    Cabin  Embarked
# 1            0         3       Braund, Mr. Owen Harris                   male    22.0  1      0      A/5 21171   7.250   NaN    S           1
# 599          0         3       Boulos, Mr. Hanna                         male    NaN   0      0      2664        7.225   NaN    C           1
# 588          1         1       Frolicher-Stehli, Mr. Maxmillian          male    60.0  1      1      13567       79.200  B41    C           1
# 589          0         3       Gilinski, Mr. Eliezer                     male    22.0  0      0      14973       8.050   NaN    S           1
# 590          0         3       Murdlin, Mr. Joseph                       male    NaN   0      0      A./5. 3235  8.050   NaN    S           1
# ...

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
 df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.shape
# Out:
# (183, 12)

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.148495 -0.089136  0.030933 -0.083488 -0.051454
# Survived        0.148495  1.000000 -0.034542 -0.254085  0.106346  0.023582
# Pclass         -0.089136 -0.034542  1.000000 -0.306514 -0.103592  0.047496
# Age             0.030933 -0.254085 -0.306514  1.000000 -0.156162 -0.271271
# SibSp          -0.083488  0.106346 -0.103592 -0.156162  1.000000  0.255346
# Parch          -0.051454  0.023582  0.047496 -0.271271  0.255346  1.000000
# Fare            0.029740  0.134241 -0.315235 -0.092424  0.286433  0.389740
#
#                  Fare
# PassengerId  0.029740
# Survived     0.134241
# Pclass      -0.315235
# Age         -0.092424
# SibSp        0.286433
# Parch        0.389740
# Fare         1.000000

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dm = dm.astype({"age": int})

# %%
dm

# %%
group=df.groupby(by=['Name','PassengerId','Survived'])

# %%
group.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df.rename(columns={"PassengerId":"passengerid","Survived":"survived","Name":"name","Sex":"sex","Age":"age","Parch":"parch","Ticket":"ticket","Fare":"fare","Cabin":"cabin"},inplace=True)

# %%
df
# Out:
#      passengerid  survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   name     sex   age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dm=df.drop(columns=['cabin'])

# %%
dm
# Out:
#      passengerid  survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   name     sex   age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dm.nlargest(1,'fare')
# Out:
#      passengerid  survived  Pclass                                name   sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
#
#       age  SibSp  parch    ticket      fare Embarked
# 679  36.0      0      1  PC 17755  512.3292        C

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## categorical plots

# %% [markdown]
# ## count of people who survived more

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',data=dm,palette='magma')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# ## Number of person who survived gender wise

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='sex',data=dm,palette='husl')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# ## count of people who survived genderwise with respect to Pclass

# %%
 sns.pointplot(x= 'Pclass', 
 y= 'survived', 

 hue='sex' , 

 data=dm,

 palette={"male": "g",

 "female":"m" },

 markers=["^" ,"o" ],

 linestyles=["-" ,"--" ])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='survived'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='Pclass',data=dm,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# ## Number of person dead or survived agewise

# %%
 sns.boxplot(x='survived', 
 y='age' ,

 hue= 'sex',

 data=dm,palette='bright')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
dm['passengerid'].value_counts().sum()
# Out:
# 183

# %% [markdown]
# # Now some visualization with some condition

# %%
survival=dm.loc[(dm['survived']==1)]

# %%
survival
# Out:
#      passengerid  survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   name     sex   age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survival.shape
# Out:
# (123, 11)

# %%
survival['passengerid'].value_counts().sum()
# Out:
# 123

# %%
sns.set(rc={"figure.figsize":(18,15)})
sns.barplot(x="Embarked",y="passengerid",data=dm,hue="sex",palette='hls').set(title="No. of person who survived gender wise")
plt.show()

# %% [markdown]
# ## Number of person whose age was greater than 30 survived

# %%
group_age=dm.loc[(dm['survived']==1) & (dm['age']>30)]

# %%
group_age
# Out:
#      passengerid  survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 21            22         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 835          836         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   name     sex  age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female   49      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
sns.set(rc={"figure.figsize":(18,15)})
sns.barplot(x="Embarked",y="age",data=group_age,hue="Embarked",palette='colorblind').set(title="People whose age was greater than 30 who survived")
plt.show()

# %%
death=dm.loc[(dm['survived']==0)]

# %%
death.head()
# Out:
#     passengerid  survived  Pclass                            name   sex  age  \
# 6             7         0       1         McCarthy, Mr. Timothy J  male   54
# 27           28         0       1  Fortune, Mr. Charles Alexander  male   19
# 54           55         0       1  Ostby, Mr. Engelhart Cornelius  male   65
# 62           63         0       1     Harris, Mr. Henry Birkhardt  male   45
# 75           76         0       3         Moen, Mr. Sigurd Hansen  male   25
#
#     SibSp  parch  ticket      fare Embarked
# 6       0      0   17463   51.8625        S
# 27      3      2   19950  263.0000        S
# 54      0      1  113509   61.9792        C
# 62      1      0   36973   83.4750        S
# 75      0      0  348123    7.6500        S

# %%
sns.set(rc={"figure.figsize":(18,15)})
sns.scatterplot(x="Embarked",y="passengerid",data=death,hue="sex").set(title="No. of person who died gender wise")
plt.show()

# %% [markdown]
# ## People died whose age was greater than 30

# %%
death_age=dm.loc[(dm['survived']==0) & (dm['age']>30)]

# %%
sns.set(rc={"figure.figsize":(18,15)})
sns.barplot(x="Embarked",y="age",data=death_age,hue="Pclass",palette='bright').set(title="People whose age was greater than 30 who died")
plt.show()

# %% [markdown]
# ## Box plot distribution of fare

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y=dm["fare"])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(dm["sex"],group_age["fare"])
plt.subplot(1,2,2)
sns.boxplot(group_age["age"],group_age["fare"])
plt.show()
# Out:
# C:\Users\siddhant gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\siddhant gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## people who was died with their siblings/spouse

# %%
death.sort_values(by=['SibSp','parch'],ascending=[False,False])
# Out:
#      passengerid  survived  Pclass  \
# 27            28         0       1
# 245          246         0       1
# 438          439         0       1
# 297          298         0       1
# 498          499         0       1
# 251          252         0       3
# 262          263         0       1
# 698          699         0       1
# 745          746         0       1
# 62            63         0       1
# 92            93         0       1
# 137          138         0       1
# 336          337         0       1
# 434          435         0       1
# 505          506         0       1
# 544          545         0       1
# 671          672         0       1
# 741          742         0       1
# 748          749         0       1
# 148          149         0       2
# 377          378         0       1
# 659          660         0       1
# 54            55         0       1
# 102          103         0       1
# 118          119         0       1
# ...

# %%
sns.set(rc={"figure.figsize":(10,8)})
sns.barplot(x="survived",y="SibSp",data=death,hue="SibSp",palette='winter').set(title="People who died with their siblings/spouse")
plt.show()

# %%
survival.sort_values(by=['SibSp','parch'],ascending=[False,False])
# Out:
#      passengerid  survived  Pclass  \
# 88            89         1       1
# 341          342         1       1
# 311          312         1       1
# 742          743         1       1
# 618          619         1       2
# ..           ...       ...     ...
# 730          731         1       1
# 759          760         1       1
# 796          797         1       1
# 862          863         1       1
# 887          888         1       1
#
#                                                   name     sex   age  SibSp  \
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 341                     Fortune, Miss. Alice Elizabeth  female  24.0      3
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 618                        Becker, Miss. Marion Louise  female   4.0      2
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## people who survived along with their parents or children

# %%
sns.set(rc={"figure.figsize":(10,8)})
sns.barplot(x="survived",y="parch",data=survival,hue="parch").set(title="People who survived along with their parents/children")
plt.show()

# %%
sns.distplot(dm["fare"],hist=False)
plt.show()
# Out:
# C:\Users\siddhant gaurav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x="age",y="sex",hue="Embarked",data=dm)
sns.set(rc={'figure.figsize':(10,5)})
plt.show()

# %%
sns.scatterplot(x="age",y="sex",hue="age",data=death_age)
sns.set(rc={'figure.figsize':(25,5)})
plt.show()

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(x="Embarked",y="age",data=dm,color='red')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(dm,hue="sex")
plt.show()

# %% [markdown]
# ## histogram plot

# %%
dm['fare'].hist(color='green',bins=40,figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
 g = sns.FacetGrid(dm, col='survived',row='sex')

# %%
 g = g.map(plt.hist,"age",color='green' )

# %% [markdown]
# ## Matrix plots

# %%
sns.heatmap(dm.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.distplot(dm[dm['survived']==0]['age'],color='red')
sns.distplot(dm[dm['survived']==1]['age'],color='green')
# Out:
# C:\Users\siddhant gaurav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\siddhant gaurav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## ACT/INSIGHTS/FINDINGS

# %% [markdown]
# ✔Chance of female survival is higher than male survival
# ✔Travelling in Pclass 3 was deadliest
# ✔Somehow, people going to C survived more
# ✔People in the age range of 20 to 40 had a higher chance of not surviving
# ✔People having more siblings/spouse survived more than who were travelling with their parent/children faced huge loss in terms of deaths.
# ✔people with pclass=1 died more as compared to other pclass
# ✔People travelling with smaller familes had a higher chance of surviving the accident in comparison to people with large families and travelling alone
#
# happy ending 🙌🙂🎉
